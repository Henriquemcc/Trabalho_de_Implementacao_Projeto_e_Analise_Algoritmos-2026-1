# %%
acuracia_dtw = [0.8763440860215054, 0.9, 0.9841772151898734, 1.0, 0.9810126582278481, 0.9066666666666666, 1.0, 0.8680555555555556]
acuracia_ddtw = [0.946236559139785, 0.8222222222222222, 0.9968354430379747, 1.0, 0.9873417721518988, 0.8266666666666667, 0.8313253012048193, 0.9722222222222222]
acuracia_lcs = [0.03763440860215054, 0.20555555555555555, 0.5253164556962026, 0.47619047619047616, 0.5063291139240507, 0.3333333333333333, 0.2931726907630522, 0.3333333333333333]
acuracia_soft_dtw = [0.8225806451612904, 0.9277777777777778, 0.9841772151898734, 1.0, 0.9873417721518988, 0.74, 1.0, 0.9583333333333334]

# %%
acuracia_media_dtw = sum(acuracia_dtw) / len(acuracia_dtw)
acuracia_media_ddtw = sum(acuracia_ddtw) / len(acuracia_ddtw)
acuracia_media_lcs = sum(acuracia_lcs) / len(acuracia_lcs)
acuracia_media_soft_dtw = sum(acuracia_soft_dtw) / len(acuracia_soft_dtw)

# %%
print('Acurácia Média DTW: {}'.format(acuracia_media_dtw))
print('Acurácia Média DDTW: {}'.format(acuracia_media_ddtw))
print('Acurácia Média LCS: {}'.format(acuracia_media_lcs))
print('Acurácia Média Soft DTW: {}'.format(acuracia_media_soft_dtw))
# Out:
# Acurácia Média DTW: 0.9395320227076811
# Acurácia Média DDTW: 0.9228562733306986
# Acurácia Média LCS: 0.3388581709247693
# Acurácia Média Soft DTW: 0.9275263429517717
